# %%
# Day 2 — Dataset Setup
import pandas as pd

# Load
df = pd.read_csv('../data/raw/creditcard.csv')

# 1. Shape
print("Shape:", df.shape)

# 2. Column names
print("\nColumns:", df.columns.tolist())

# 3. First few rows
df.head()
