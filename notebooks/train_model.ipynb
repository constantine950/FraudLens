# %%
# Cell 1 — Imports
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import joblib
import os

X_train = pd.read_csv('../data/processed/X_train.csv')
y_train = pd.read_csv('../data/processed/y_train.csv').values.ravel()

print("Train shape:", X_train.shape)
print("Labels:", pd.Series(y_train).value_counts().to_dict())
# Out:
# Train shape: (454902, 30)
# Labels: {0: 227451, 1: 227451}

# %%
# Cell 2 — Train Logistic Regression (fast baseline)
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
print("✅ Logistic Regression trained")
# Out:
# ✅ Logistic Regression trained

# %%
# Cell 3 — Train Random Forest (stronger model)
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)
print("✅ Random Forest trained")

# %%
# Cell 4 — Save both models
os.makedirs('../backend/models', exist_ok=True)

joblib.dump(lr, '../backend/models/logistic_model.pkl')
joblib.dump(rf, '../backend/models/random_forest_model.pkl')

print("✅ Models saved to backend/models/")
